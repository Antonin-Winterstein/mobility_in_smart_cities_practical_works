# %% [markdown]
# # Transitivity - Check if a matrix is transitive

# %%
def is_matrix_transitive(matrix):
  # Initialize a variable to check if the relation is transitive
  is_transitive = True
  # Iterate through the rows (i) and columns (j) of the array
  for i in range(len(matrix)):
      for j in range(len(matrix[i])):
          # Check for a valid relation (x, y)
          if matrix[i][j]:
              # Look for (y, z) in the y-line only
              for k in range(len(matrix[j])):
                  if matrix[j][k]:
                      # Verify if matrix[x, k] exists
                      if not matrix[i][k]:
                          # Transitive property violated
                          is_transitive = False
                          break  # No need to continue checking
          else:
              continue  # No relation for (x, y), move to the next element

  return is_transitive

# %%
matrix = [
    [1, 1, 1],
    [0, 1, 1],
    [0, 0, 1]]

print("Original Matrix:")
for row in matrix:
    print(row)

# Print the result
if is_matrix_transitive(matrix) == True:
    print("The relation is transitive.")
else:
    print("The relation is not transitive.")
# Out:
# Original Matrix:
# [1, 1, 1]
# [0, 1, 1]
# [0, 0, 1]
# The relation is transitive.

# %%
matrix = [
    [1, 1, 0],
    [0, 1, 1],
    [0, 0, 1]]

print("Original Matrix:")
for row in matrix:
    print(row)

# Print the result
if is_transitive(matrix) == True:
    print("The relation is transitive.")
else:
    print("The relation is not transitive.")
# Out:
# Original Matrix:
# [1, 1, 0]
# [0, 1, 1]
# [0, 0, 1]
# The relation is not transitive.
